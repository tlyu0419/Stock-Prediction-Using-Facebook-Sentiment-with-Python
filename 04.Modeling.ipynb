# %% [markdown]
# # Modeling
# - NCCU PyDay 2022: https://www.facebook.com/groups/pythontw/posts/10162007038723438/
# - Author: TENG-LIN YU
# - Email: tlyu0419@gmail.com
# - Github: https://github.com/TLYu0419/Stock-Prediction-Using-Facebook-Sentiment-with-Python

# %% [markdown]
# ## 實驗設計
#   - 1: 情感預測波動
#   - 2: 情感預測股價
#   - 2: 過去的股價+情感 預測今天的股價
#     - QA: 如何抓過去幾天的?
#     - Stock Prediction Using Twitter Sentiment Analysis
#   - 3: 預測股價還是預測波動

# %% [markdown]
# ## Import packages

# %%
# !pip install statsmodels

# %%
import numpy as np
import pandas as pd
import datetime
from sklearn.preprocessing import StandardScaler
from statsmodels.tsa.stattools import grangercausalitytests

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.model_selection import TimeSeriesSplit
import statsmodels.api as sm
import seaborn as sns

# %%
pd.set_option('display.max_columns', 100)
# pd.set_option('display.max_rows', 300)

# %% [markdown]
# ## Load Data

# %%
stock_price = pd.read_pickle('./stock_price_by_date.pickle')
stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
stock_price
# Out:
#            DATE  CLOSING_INDEX
# 0    2020-12-01       13885.67
# 1    2020-12-02       13989.14
# 2    2020-12-03       13977.09
# 3    2020-12-04       14132.44
# 4    2020-12-05       14194.52
# ..          ...            ...
# 503  2022-04-18       16898.87
# 504  2022-04-19       16993.40
# 505  2022-04-20       17148.88
# 506  2022-04-21       17127.95
# 507  2022-04-22       17025.09
#
# [508 rows x 2 columns]

# %%
sentiment = pd.read_pickle('./sentiment_by_date.pickle')
sentiment = sentiment.reset_index()
sentiment
# Out:
#            DATE    LIKE   HAHA  LOVE   WOW  CARE  ANGRY   SAD
# 0    2020-12-24     199      0     2     0     0      0     0
# 1    2020-12-28    1257      0    14     4     1      0     0
# 2    2020-12-29    3159     21    21     3     2      0     2
# 3    2020-12-30    9448    541    44   309    10      0    13
# 4    2020-12-31   14667    671   210    32    24     29     7
# ..          ...     ...    ...   ...   ...   ...    ...   ...
# 477  2022-04-18  120844  33551   721  2228   979    597  3694
# 478  2022-04-19   65164   4433  1197  1934   448    186   853
# 479  2022-04-20   75773   9032   464  1925   240    344   226
# 480  2022-04-21   31128   2935   504  1373   382    700   129
# 481  2022-04-22       9      0     1     0     0      0     0
#
# [482 rows x 8 columns]

# %%
df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
df
# Out:
#            DATE  CLOSING_INDEX      LIKE     HAHA    LOVE     WOW   CARE  \
# 0    2020-12-01       13885.67       NaN      NaN     NaN     NaN    NaN
# 1    2020-12-02       13989.14       NaN      NaN     NaN     NaN    NaN
# 2    2020-12-03       13977.09       NaN      NaN     NaN     NaN    NaN
# 3    2020-12-04       14132.44       NaN      NaN     NaN     NaN    NaN
# 4    2020-12-05       14194.52       NaN      NaN     NaN     NaN    NaN
# ..          ...            ...       ...      ...     ...     ...    ...
# 503  2022-04-18       16898.87  120844.0  33551.0   721.0  2228.0  979.0
# 504  2022-04-19       16993.40   65164.0   4433.0  1197.0  1934.0  448.0
# 505  2022-04-20       17148.88   75773.0   9032.0   464.0  1925.0  240.0
# 506  2022-04-21       17127.95   31128.0   2935.0   504.0  1373.0  382.0
# 507  2022-04-22       17025.09       9.0      0.0     1.0     0.0    0.0
#
#      ANGRY     SAD
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# ..     ...     ...
# 503  597.0  3694.0
# 504  186.0   853.0
# 505  344.0   226.0
# 506  700.0   129.0
# 507    0.0     0.0
#
# [508 rows x 9 columns]

# %%
# df = df.loc[df['DATE'].apply(lambda x: '2021-07-01' <= x <= '2022-04-20')]
df = df.loc[df['DATE'].apply(lambda x: '2021-01-01' <= x <= '2021-12-31')]
df
# # df = df.loc[df['DATE'].apply(lambda x: '2021-10-01' <= x <= '2022-04-17')]
# print(df['DATE'].min())
# print(df['DATE'].max())
# Out:
#            DATE  CLOSING_INDEX     LIKE    HAHA   LOVE    WOW   CARE  ANGRY  \
# 31   2021-01-01     14817.2800  17495.0   175.0  112.0  125.0    9.0   24.0
# 32   2021-01-02     14859.6550   8691.0   291.0   73.0   79.0   14.0    7.0
# 33   2021-01-03     14880.8425   4966.0   142.0   36.0  103.0    6.0    2.0
# 34   2021-01-04     14902.0300  26926.0  2680.0  176.0  278.0   44.0    9.0
# 35   2021-01-05     15000.0300   9681.0   617.0   37.0  132.0    6.0   11.0
# ..          ...            ...      ...     ...    ...    ...    ...    ...
# 391  2021-12-27     18048.9400  14183.0   523.0   82.0  228.0   41.0  157.0
# 392  2021-12-28     18196.8100  37211.0  1896.0  172.0  220.0  547.0  483.0
# 393  2021-12-29     18248.2800  14600.0  1255.0   65.0  192.0   18.0   11.0
# 394  2021-12-30     18218.8400  22604.0  2276.0  173.0  899.0   62.0  165.0
# 395  2021-12-31     18244.6750  48621.0   996.0  385.0  272.0   75.0   22.0
#
#        SAD
# 31     5.0
# 32    13.0
# 33    12.0
# 34    41.0
# 35     4.0
# ..     ...
# 391   77.0
# 392  111.0
# 393   60.0
# 394  169.0
# 395   24.0
#
# [365 rows x 9 columns]

# %%
df = df.set_index('DATE')
std = StandardScaler()
df = pd.DataFrame(std.fit_transform(df), columns=df.columns, index=df.index)
df
# Out:
#             CLOSING_INDEX      LIKE      HAHA      LOVE       WOW      CARE  \
# DATE
# 2021-01-01      -2.829343 -0.021187 -0.606136 -0.103150 -0.616975 -0.648357
# 2021-01-02      -2.772029 -1.047360 -0.548314 -0.304623 -0.818799 -0.581878
# 2021-01-03      -2.743373 -1.481538 -0.622585 -0.495764 -0.713500 -0.688244
# 2021-01-04      -2.714716  1.078068  0.642510  0.227473  0.054309 -0.183007
# 2021-01-05      -2.582167 -0.931968 -0.385816 -0.490598 -0.586263 -0.688244
# ...                   ...       ...       ...       ...       ...       ...
# 2021-12-27       1.541598 -0.407226 -0.432671 -0.258129 -0.165065 -0.222894
# 2021-12-28       1.741598  2.276864  0.251716  0.206809 -0.200165  6.504734
# 2021-12-29       1.811213 -0.358621 -0.067798 -0.345950 -0.323014 -0.528696
# 2021-12-30       1.771394  0.574306  0.441131  0.211975  2.778930  0.056316
# 2021-12-31       1.806337  3.606786 -0.196899  1.307161  0.027984  0.229160
#
#                ANGRY       SAD
# DATE
# 2021-01-01 -0.288258 -0.479160
# 2021-01-02 -0.453689 -0.420468
# 2021-01-03 -0.502345 -0.427805
# 2021-01-04 -0.434226 -0.215048
# 2021-01-05 -0.414764 -0.486496
# ...              ...       ...
# 2021-12-27  1.005996  0.049064
# 2021-12-28  4.178378  0.298503
# 2021-12-29 -0.414764 -0.075656
# 2021-12-30  1.083846  0.724016
# 2021-12-31 -0.307720 -0.339768
#
# [365 rows x 8 columns]

# %%
# df['N1D_CLOSING_INDEX'] = df['CLOSING_INDEX'].shift(-1)
# df['DIFF'] = df['N1D_CLOSING_INDEX'] - df['CLOSING_INDEX']
# df['DIRECT'] = df['DIFF'].apply(lambda x: int(x>0))
# df['LIKE'] = np.log(df['LIKE'])
# df['HAHA'] = np.log(df['HAHA'])
# df['LOVE'] = np.log(df['LOVE'])
# df['WOW'] = np.log(df['WOW'])
# df['CARE'] = np.log(df['CARE'])
# df['ANGRY'] = np.log(df['ANGRY']+1)
# df['SAD'] = np.log(df['SAD'])
# df

# df = df.loc[df['DATE'].apply(lambda x: '2021-12-01' <= x <= '2022-04-17')]
# # df = df.loc[df['DATE'].apply(lambda x: '2021-10-01' <= x <= '2022-04-17')]
# print(df['DATE'].min())
# print(df['DATE'].max())

# %%
# std = StandardScaler()
# columns = ['CLOSING_INDEX', 'LIKE', 'HAHA', 'LOVE', 'WOW', 'CARE', 'ANGRY', 'SAD']
# df = pd.DataFrame(std.fit_transform(df[columns]), columns=columns, index=df['DATE'])
# df

# %% [markdown]
# ## Granger causality
# - The Granger Causality test is used to determine whether or not one time series is useful for forecasting another.
# - https://www.statology.org/granger-causality-test-in-python/
# - https://www.youtube.com/watch?v=4TkNZviNJC0

# %%
#perform Granger-Causality test
print('======================= LIKE =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'LIKE']], maxlag=5)
print('======================= HAHA =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'HAHA']], maxlag=5)
print('======================= LOVE =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'LOVE']], maxlag=5)
print('======================= WOW========================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'WOW']], maxlag=5)
print('======================= CARE =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'CARE']], maxlag=5)
print('======================= ANGRY =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'ANGRY']], maxlag=5)
print('======================= SAD =======================')
result = grangercausalitytests(df[['CLOSING_INDEX', 'SAD']], maxlag=5)
# Out:
# ======================= LIKE =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.2507  , p=0.6169  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.2528  , p=0.6151  , df=1
# likelihood ratio test: chi2=0.2527  , p=0.6152  , df=1
# parameter F test:         F=0.2507  , p=0.6169  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3054  , p=0.7370  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.6193  , p=0.7337  , df=2
# likelihood ratio test: chi2=0.6188  , p=0.7339  , df=2
# parameter F test:         F=0.3054  , p=0.7370  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3308  , p=0.8031  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.0119  , p=0.7984  , df=3
# likelihood ratio test: chi2=1.0105  , p=0.7987  , df=3
# parameter F test:         F=0.3308  , p=0.8031  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.8230  , p=0.5112  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.3761  , p=0.4970  , df=4
# likelihood ratio test: chi2=3.3604  , p=0.4994  , df=4
# parameter F test:         F=0.8230  , p=0.5112  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1615  , p=0.3277  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=5.9908  , p=0.3071  , df=5
# likelihood ratio test: chi2=5.9415  , p=0.3120  , df=5
# parameter F test:         F=1.1615  , p=0.3277  , df_denom=349, df_num=5
# ======================= HAHA =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0062  , p=0.9373  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0062  , p=0.9370  , df=1
# likelihood ratio test: chi2=0.0062  , p=0.9370  , df=1
# parameter F test:         F=0.0062  , p=0.9373  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.1919  , p=0.8255  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.3891  , p=0.8232  , df=2
# likelihood ratio test: chi2=0.3889  , p=0.8233  , df=2
# parameter F test:         F=0.1919  , p=0.8255  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1800  , p=0.9100  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=0.5506  , p=0.9077  , df=3
# likelihood ratio test: chi2=0.5501  , p=0.9077  , df=3
# parameter F test:         F=0.1800  , p=0.9100  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.2157  , p=0.9296  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=0.8850  , p=0.9267  , df=4
# likelihood ratio test: chi2=0.8839  , p=0.9269  , df=4
# parameter F test:         F=0.2157  , p=0.9296  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.4175  , p=0.8365  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.1533  , p=0.8275  , df=5
# likelihood ratio test: chi2=2.1469  , p=0.8285  , df=5
# parameter F test:         F=0.4175  , p=0.8365  , df_denom=349, df_num=5
# ======================= LOVE =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4895  , p=0.4846  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.4935  , p=0.4824  , df=1
# likelihood ratio test: chi2=0.4932  , p=0.4825  , df=1
# parameter F test:         F=0.4895  , p=0.4846  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5615  , p=0.5708  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.1388  , p=0.5659  , df=2
# likelihood ratio test: chi2=1.1370  , p=0.5664  , df=2
# parameter F test:         F=0.5615  , p=0.5708  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.3650  , p=0.7783  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.1166  , p=0.7731  , df=3
# likelihood ratio test: chi2=1.1148  , p=0.7735  , df=3
# parameter F test:         F=0.3650  , p=0.7783  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3383  , p=0.8521  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.3879  , p=0.8463  , df=4
# likelihood ratio test: chi2=1.3852  , p=0.8468  , df=4
# parameter F test:         F=0.3383  , p=0.8521  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2543  , p=0.9375  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=1.3114  , p=0.9337  , df=5
# likelihood ratio test: chi2=1.3091  , p=0.9340  , df=5
# parameter F test:         F=0.2543  , p=0.9375  , df_denom=349, df_num=5
# ======================= WOW========================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.4527  , p=0.5015  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.4564  , p=0.4993  , df=1
# likelihood ratio test: chi2=0.4561  , p=0.4994  , df=1
# parameter F test:         F=0.4527  , p=0.5015  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.3713  , p=0.6901  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=0.7529  , p=0.6863  , df=2
# likelihood ratio test: chi2=0.7522  , p=0.6865  , df=2
# parameter F test:         F=0.3713  , p=0.6901  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4017  , p=0.7519  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.2288  , p=0.7461  , df=3
# likelihood ratio test: chi2=1.2267  , p=0.7466  , df=3
# parameter F test:         F=0.4017  , p=0.7519  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.7473  , p=0.5603  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=3.0656  , p=0.5469  , df=4
# likelihood ratio test: chi2=3.0526  , p=0.5491  , df=4
# parameter F test:         F=0.7473  , p=0.5603  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9472  , p=0.4505  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=4.8850  , p=0.4301  , df=5
# likelihood ratio test: chi2=4.8522  , p=0.4342  , df=5
# parameter F test:         F=0.9472  , p=0.4505  , df_denom=349, df_num=5
# ======================= CARE =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0495  , p=0.8240  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0499  , p=0.8232  , df=1
# likelihood ratio test: chi2=0.0499  , p=0.8232  , df=1
# parameter F test:         F=0.0495  , p=0.8240  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.5293  , p=0.5895  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=1.0733  , p=0.5847  , df=2
# likelihood ratio test: chi2=1.0717  , p=0.5852  , df=2
# parameter F test:         F=0.5293  , p=0.5895  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.4413  , p=0.7236  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=1.3500  , p=0.7173  , df=3
# likelihood ratio test: chi2=1.3474  , p=0.7179  , df=3
# parameter F test:         F=0.4413  , p=0.7236  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.3935  , p=0.8133  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=1.6142  , p=0.8062  , df=4
# likelihood ratio test: chi2=1.6106  , p=0.8069  , df=4
# parameter F test:         F=0.3935  , p=0.8133  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2953  , p=0.9154  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=1.5229  , p=0.9104  , df=5
# likelihood ratio test: chi2=1.5197  , p=0.9108  , df=5
# parameter F test:         F=0.2953  , p=0.9154  , df_denom=349, df_num=5
# ======================= ANGRY =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=7.0302  , p=0.0084  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=7.0886  , p=0.0078  , df=1
# likelihood ratio test: chi2=7.0205  , p=0.0081  , df=1
# parameter F test:         F=7.0302  , p=0.0084  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4053  , p=0.0343  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=6.9058  , p=0.0317  , df=2
# likelihood ratio test: chi2=6.8409  , p=0.0327  , df=2
# parameter F test:         F=3.4053  , p=0.0343  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.4078  , p=0.0669  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=7.3659  , p=0.0611  , df=3
# likelihood ratio test: chi2=7.2919  , p=0.0632  , df=3
# parameter F test:         F=2.4078  , p=0.0669  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.7375  , p=0.1412  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=7.1276  , p=0.1293  , df=4
# likelihood ratio test: chi2=7.0581  , p=0.1328  , df=4
# parameter F test:         F=1.7375  , p=0.1412  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.3740  , p=0.2334  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=7.0864  , p=0.2143  , df=5
# likelihood ratio test: chi2=7.0175  , p=0.2193  , df=5
# parameter F test:         F=1.3740  , p=0.2334  , df_denom=349, df_num=5
# ======================= SAD =======================
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.0680  , p=0.7944  , df_denom=361, df_num=1
# ssr based chi2 test:   chi2=0.0686  , p=0.7934  , df=1
# likelihood ratio test: chi2=0.0686  , p=0.7934  , df=1
# parameter F test:         F=0.0680  , p=0.7944  , df_denom=361, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.2620  , p=0.2843  , df_denom=358, df_num=2
# ssr based chi2 test:   chi2=2.5593  , p=0.2781  , df=2
# likelihood ratio test: chi2=2.5504  , p=0.2794  , df=2
# parameter F test:         F=1.2620  , p=0.2843  , df_denom=358, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.0679  , p=0.3627  , df_denom=355, df_num=3
# ssr based chi2 test:   chi2=3.2668  , p=0.3523  , df=3
# likelihood ratio test: chi2=3.2521  , p=0.3544  , df=3
# parameter F test:         F=1.0679  , p=0.3627  , df_denom=355, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.6622  , p=0.6187  , df_denom=352, df_num=4
# ssr based chi2 test:   chi2=2.7163  , p=0.6064  , df=4
# likelihood ratio test: chi2=2.7062  , p=0.6081  , df=4
# parameter F test:         F=0.6622  , p=0.6187  , df_denom=352, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.5779  , p=0.7169  , df_denom=349, df_num=5
# ssr based chi2 test:   chi2=2.9807  , p=0.7030  , df=5
# likelihood ratio test: chi2=2.9684  , p=0.7049  , df=5
# parameter F test:         F=0.5779  , p=0.7169  , df_denom=349, df_num=5

# %% [markdown]
# ## Set of Features
# - Feature:
#   - 0.05
#     - LIKE > 3D
#     - WOW > 3D
#   - ELSE
#     - HAHA > 2D
#     - SAD > 2D
#     - LOVE > 1D
#     - WOW > 1D
#     - ANGET > 1D
# -  To confirm the inverse dependence of other mood dimensions on TWSE we investigated a total of 4 different possibilities.
#    - Module 1: $ L3D\_LIKE $
#    - Module 2: $ L3D\_WOW $
#    - Module 3: $ L3D\_LIKE + L3D\_WOW $
#    - Module 4: $ L3D\_LIKE + L3D\_WOW + HAHA + LOVE + CARE + ANGRY + SAD$

# %%
stock_price = pd.read_pickle('./stock_price_by_date.pickle')
stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
sentiment = pd.read_pickle('./sentiment_by_date.pickle')
df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
df = df.loc[df['DATE'].apply(lambda x: '2021-07-01' <= x <= '2022-04-20')]
df
# Out:
#            DATE  CLOSING_INDEX      LIKE     HAHA    LOVE     WOW   CARE  \
# 212  2021-07-01     17713.9400    6508.0    141.0    91.0    53.0   12.0
# 213  2021-07-02     17710.1500   25305.0   3227.0   185.0   386.0   36.0
# 214  2021-07-03     17814.7400   11057.0    113.0    53.0    48.0   11.0
# 215  2021-07-04     17867.0350   15265.0    442.0    50.0    60.0   22.0
# 216  2021-07-05     17919.3300   20673.0    469.0   126.0   992.0   53.0
# ..          ...            ...       ...      ...     ...     ...    ...
# 501  2022-04-16     16951.5250   82358.0  10830.0  3662.0  2802.0  355.0
# 502  2022-04-17     16925.1975   92631.0  14661.0  3095.0   996.0  484.0
# 503  2022-04-18     16898.8700  120844.0  33551.0   721.0  2228.0  979.0
# 504  2022-04-19     16993.4000   65164.0   4433.0  1197.0  1934.0  448.0
# 505  2022-04-20     17148.8800   75773.0   9032.0   464.0  1925.0  240.0
#
#      ANGRY     SAD
# 212   40.0     9.0
# 213   61.0    33.0
# 214    9.0     4.0
# 215   12.0     6.0
# 216   12.0   833.0
# ..     ...     ...
# 501  175.0   260.0
# 502  601.0   311.0
# 503  597.0  3694.0
# 504  186.0   853.0
# 505  344.0   226.0
#
# [294 rows x 9 columns]

# %%
stock_price = pd.read_pickle('./stock_price_by_date.pickle')
stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
sentiment = pd.read_pickle('./sentiment_by_date.pickle')
df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
df
# Out:
#            DATE  CLOSING_INDEX   LIKE  HAHA  LOVE   WOW  CARE  ANGRY  SAD
# 0    2021-07-01     17713.9400   6509   141    91    53    12     40    9
# 1    2021-07-02     17710.1500  25305  3227   185   386    36     61   33
# 2    2021-07-03     17814.7400  11057   113    53    48    11      9    4
# 3    2021-07-04     17867.0350  15266   442    50    60    22     12    6
# 4    2021-07-05     17919.3300  20674   469   126   992    53     12  833
# ..          ...            ...    ...   ...   ...   ...   ...    ...  ...
# 287  2022-04-14     17245.6500  80054  9636   989  1610  1210    619  253
# 288  2022-04-15     17004.1800  60520  8634   451  1869   222    343  259
# 289  2022-04-16     16951.5250  68885  8800  3096  2266   284    158  229
# 290  2022-04-17     16925.1975  61989  9211  1811   845   308    560  222
# 291  2022-04-18     16898.8700  18213  5001   157   269    99    182   54
#
# [292 rows x 9 columns]

# %%
df['LIKE'].rolling(2).sum()
# Out:
# 0           NaN
# 1       31814.0
# 2       36362.0
# 3       26323.0
# 4       35940.0
#          ...
# 287    141368.0
# 288    140574.0
# 289    129405.0
# 290    130874.0
# 291     80202.0
# Name: LIKE, Length: 292, dtype: float64

# %%
df['L3D_LIKE'] = df['LIKE'].rolling(3).sum()
df['L3D_WOW'] = df['WOW'].rolling(3).sum()

df['N1D_CLOSING_INDEX'] = df['CLOSING_INDEX'].shift(-1)
df['DIFF'] = df['N1D_CLOSING_INDEX'] - df['CLOSING_INDEX']
df['DIRECT'] = df['DIFF'].apply(lambda x: int(x>0))
df['L3D_LIKE'] = np.log(df['L3D_LIKE'])
df['HAHA'] = np.log(df['HAHA'])
df['LOVE'] = np.log(df['LOVE'])
df['L3D_WOW'] = np.log(df['L3D_WOW'])
df['CARE'] = np.log(df['CARE'])
df['ANGRY'] = np.log(df['ANGRY']+1)
df['SAD'] = np.log(df['SAD'])

training = df.loc[df['DATE'].apply(lambda x: '2021-12-01' <= x <= '2022-02-28')]
testing = df.loc[df['DATE'].apply(lambda x: '2022-03-01' <= x <= '2022-04-17')]

df
# Out:
#            DATE  CLOSING_INDEX   LIKE      HAHA      LOVE   WOW      CARE  \
# 0    2021-07-01     17713.9400   6509  4.948760  4.510860    53  2.484907
# 1    2021-07-02     17710.1500  25305  8.079308  5.220356   386  3.583519
# 2    2021-07-03     17814.7400  11057  4.727388  3.970292    48  2.397895
# 3    2021-07-04     17867.0350  15266  6.091310  3.912023    60  3.091042
# 4    2021-07-05     17919.3300  20674  6.150603  4.836282   992  3.970292
# ..          ...            ...    ...       ...       ...   ...       ...
# 287  2022-04-14     17245.6500  80054  9.173261  6.896694  1610  7.098376
# 288  2022-04-15     17004.1800  60520  9.063463  6.111467  1869  5.402677
# 289  2022-04-16     16951.5250  68885  9.082507  8.037866  2266  5.648974
# 290  2022-04-17     16925.1975  61989  9.128154  7.501634   845  5.730100
# 291  2022-04-18     16898.8700  18213  8.517393  5.056246   269  4.595120
#
#         ANGRY       SAD   L3D_LIKE   L3D_WOW  N1D_CLOSING_INDEX      DIFF  \
# 0    3.713572  2.197225        NaN       NaN         17710.1500   -3.7900
# 1    4.127134  3.496508        NaN       NaN         17814.7400  104.5900
# 2    2.302585  1.386294  10.665951  6.188264         17867.0350   52.2950
# 3    2.564949  1.791759  10.851819  6.202536         17919.3300   52.2950
# 4    2.564949  6.725034  10.757839  7.003065         17913.0700   -6.2600
# ..        ...       ...        ...       ...                ...       ...
# 287  6.429719  5.533389  12.288279  8.320205         17004.1800 -241.4700
# 288  5.840642  5.556828  12.215468  8.518592         16951.5250  -52.6550
# 289  5.068904  5.433722  12.252283  8.656085         16925.1975  -26.3275
# 290  6.329721  5.402677  12.162089  8.513185         16898.8700  -26.3275
# 291  5.209486  3.988984  11.912285  8.125631                NaN       NaN
#
#      DIRECT
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
# ..      ...
# 287       0
# 288       0
# 289       0
# 290       0
# 291       0
#
# [292 rows x 14 columns]

# %%
module1 = ['L3D_LIKE']
module2 = ['L3D_WOW']
module3 = ['L3D_LIKE', 'L3D_WOW']
module4 = ['L3D_LIKE', 'L3D_WOW', 'HAHA', 'LOVE', 'CARE', 'ANGRY', 'SAD']
target = ['DIFF']

# %% [markdown]
# ## 模型
# - Model
#   - Regression
#     - LR
#     - SVR
#     - MAP
#   - Classfication
#     - Logistic Regression
#     - SVM
#     - MAP
#     - SOFNN
# - KSVC
# - [Normalization vs Standardization in Linear Regression](https://www.baeldung.com/cs/normalization-vs-standardization)

# %%
regressor = LinearRegression()
regressor.fit(training[module1], training[target])
print(regressor.score(training[module1], training[target]))
print(regressor.score(testing[module1], testing[target]))
# Out:
# 0.025613870700517127
# -0.018584499614078265

# %%
regressor = LinearRegression()
regressor.fit(training[module2], training[target])
print(regressor.score(training[module2], training[target]))
print(regressor.score(testing[module2], testing[target]))
# Out:
# 0.00785544992759768
# 0.007138808945051478

# %%
regressor = LinearRegression()
regressor.fit(training[module3], training[target])
print(regressor.score(training[module3], training[target]))
print(regressor.score(testing[module3], testing[target]))
# Out:
# 0.028728866042186718
# -0.0363887264410363

# %%
regressor = LinearRegression()
regressor.fit(training[module4], training[target])
print(regressor.score(training[module4], training[target]))
print(regressor.score(testing[module4], testing[target]))
# Out:
# 0.06747745167530583
# -0.093150218678405

# %%
# statmodels
training2 = training[module2]
training2 = sm.add_constant(training2, prepend=False)

# Fit and summarize OLS model
mod = sm.OLS(training[target], training2)
res = mod.fit()

print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   DIFF   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.6968
# Date:                Tue, 19 Apr 2022   Prob (F-statistic):              0.406
# Time:                        23:18:18   Log-Likelihood:                -549.20
# No. Observations:                  90   AIC:                             1102.
# Df Residuals:                      88   BIC:                             1107.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L3D_WOW      -15.2399     18.258     -0.835      0.406     -51.523      21.043
# const        112.9155    131.623      0.858      0.393    -148.658     374.488
# ==============================================================================
# Omnibus:                       26.178   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               59.446
# Skew:                          -1.023   Prob(JB):                     1.23e-13
# Kurtosis:                       6.416   Cond. No.                         83.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### MOVEMENT2
# - log

# %%
# stock_price = pd.read_pickle('./stock_price_by_date.pickle')
# stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
# sentiment = pd.read_pickle('./sentiment_by_date.pickle')
# df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
# df

# %%
# df = df.loc[df['DATE'].apply(lambda x: '2021-12-01' <= x <= '2022-04-18')]

# df['LIKE'] = np.log(df['LIKE'])
# df['HAHA'] = np.log(df['HAHA'])
# df['LOVE'] = np.log(df['LOVE'])
# df['WOW'] = np.log(df['WOW'])
# df['CARE'] = np.log(df['CARE'])
# df['ANGRY'] = np.log(df['ANGRY']+1)
# df['SAD'] = np.log(df['SAD'])
# df

# %%
# df['N1D_CLOSING_INDEX'] = df['CLOSING_INDEX'].shift(-1)

# df['MOVEMENT'] = df['N1D_CLOSING_INDEX'] - df['CLOSING_INDEX'] 

# std = StandardScaler()
# df['CLOSING_INDEX'] = std.fit_transform(df[['CLOSING_INDEX']])


# training = df.loc[df['DATE'].apply(lambda x: '2021-12-01' <= x <= '2022-02-28')]
# testing = df.loc[df['DATE'].apply(lambda x: '2022-03-01' <= x <= '2022-04-17')]
# df

# %%
# module1 = ['CLOSING_INDEX']
# module2 = ['CLOSING_INDEX', 'LIKE']
# module3 = ['CLOSING_INDEX', 'CARE']
# module4 = ['CLOSING_INDEX', 'LIKE', 'CARE']
# module5 = ['CLOSING_INDEX', 'LIKE', 'CARE', 'HAHA', 'SAD']
# module6 = ['CLOSING_INDEX', 'LIKE', 'CARE', 'HAHA', 'SAD', 'LOVE', 'WOW', 'ANGRY']
# target = ['MOVEMENT']

# %%
# regressor = LinearRegression()
# regressor.fit(training[module1], training[target])
# print(regressor.score(training[module1], training[target]))
# print(regressor.score(testing[module1], testing[target]))
# Out:
# 0.06191251813896914
# -0.22826208289002614

# %%
regressor = LinearRegression()
regressor.fit(training[module2], training[target])
print(regressor.score(training[module2], training[target]))
print(regressor.score(testing[module2], testing[target]))
# Out:
# 0.08168283744024618
# -0.09099626669944638

# %%
regressor = LinearRegression()
regressor.fit(training[module3], training[target])
print(regressor.score(training[module3], training[target]))
print(regressor.score(testing[module3], testing[target]))
# Out:
# 0.06730202968278653
# -0.16471371009719915

# %%
regressor = LinearRegression()
regressor.fit(training[module4], training[target])
print(regressor.score(training[module4], training[target]))
print(regressor.score(testing[module4], testing[target]))
# Out:
# 0.08411779753685056
# -0.0982771618269993

# %%
regressor = LinearRegression()
regressor.fit(training[module5], training[target])
print(regressor.score(training[module5], training[target]))
print(regressor.score(testing[module5], testing[target]))
# Out:
# 0.08681091957530562
# -0.07651330872749029

# %%
regressor = LinearRegression()
regressor.fit(training[module6], training[target])
print(regressor.score(training[module6], training[target]))
print(regressor.score(testing[module6], testing[target]))
# Out:
# 0.10317449594670913
# -0.1377301947593026

# %% [markdown]
# ### MOVEMENT3
# - percent

# %%
# stock_price = pd.read_pickle('./stock_price_by_date.pickle')
# stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
# sentiment = pd.read_pickle('./sentiment_by_date.pickle')
# df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
# df

# %% [markdown]
# ### MOVEMENT_DIRECT

# %%
stock_price = pd.read_pickle('./stock_price_by_date.pickle')
stock_price['DATE'] = stock_price['DATE'].apply(lambda x: x.strftime('%Y-%m-%d'))
sentiment = pd.read_pickle('./sentiment_by_date.pickle')
df = pd.merge(left=stock_price, right=sentiment, how='left', on='DATE')
df
# Out:
#            DATE  CLOSING_INDEX   LIKE  HAHA  LOVE   WOW  CARE  ANGRY  SAD
# 0    2021-07-01     17713.9400   6509   141    91    53    12     40    9
# 1    2021-07-02     17710.1500  25305  3227   185   386    36     61   33
# 2    2021-07-03     17814.7400  11057   113    53    48    11      9    4
# 3    2021-07-04     17867.0350  15266   442    50    60    22     12    6
# 4    2021-07-05     17919.3300  20674   469   126   992    53     12  833
# ..          ...            ...    ...   ...   ...   ...   ...    ...  ...
# 287  2022-04-14     17245.6500  80054  9636   989  1610  1210    619  253
# 288  2022-04-15     17004.1800  60520  8634   451  1869   222    343  259
# 289  2022-04-16     16951.5250  68885  8800  3096  2266   284    158  229
# 290  2022-04-17     16925.1975  61989  9211  1811   845   308    560  222
# 291  2022-04-18     16898.8700  18213  5001   157   269    99    182   54
#
# [292 rows x 9 columns]

# %%
df['N1D_CLOSING_INDEX'] = df['CLOSING_INDEX'].shift(-1)
df['DIRECTED'] = df['N1D_CLOSING_INDEX'] - df['CLOSING_INDEX']
df['DIRECTED2'] = df['DIRECTED'].apply(lambda x: int(x>0))

df.loc[:,['LIKE']] = np.log(df['LIKE'])
df.loc[:,['HAHA']] = np.log(df['HAHA'])
df.loc[:,['LOVE']] = np.log(df['LOVE'])
df.loc[:,['WOW']] = np.log(df['WOW'])
df.loc[:,['CARE']] = np.log(df['CARE'])
df.loc[:,['ANGRY']] = np.log(df['ANGRY']+1)
df.loc[:,['SAD']] = np.log(df['SAD'])

training = df.loc[df['DATE'].apply(lambda x: '2021-12-01' <= x <= '2022-02-31')]
testing = df.loc[df['DATE'].apply(lambda x: '2022-03-01' <= x <= '2022-04-17')]
df
# Out:
#            DATE  CLOSING_INDEX       LIKE      HAHA      LOVE       WOW  \
# 0    2021-07-01     17713.9400   8.780941  4.948760  4.510860  3.970292
# 1    2021-07-02     17710.1500  10.138757  8.079308  5.220356  5.955837
# 2    2021-07-03     17814.7400   9.310819  4.727388  3.970292  3.871201
# 3    2021-07-04     17867.0350   9.633383  6.091310  3.912023  4.094345
# 4    2021-07-05     17919.3300   9.936632  6.150603  4.836282  6.899723
# ..          ...            ...        ...       ...       ...       ...
# 287  2022-04-14     17245.6500  11.290457  9.173261  6.896694  7.383989
# 288  2022-04-15     17004.1800  11.010729  9.063463  6.111467  7.533159
# 289  2022-04-16     16951.5250  11.140194  9.082507  8.037866  7.725771
# 290  2022-04-17     16925.1975  11.034712  9.128154  7.501634  6.739337
# 291  2022-04-18     16898.8700   9.809891  8.517393  5.056246  5.594711
#
#          CARE     ANGRY       SAD  N1D_CLOSING_INDEX  DIRECTED  DIRECTED2
# 0    2.484907  3.713572  2.197225         17710.1500   -3.7900          0
# 1    3.583519  4.127134  3.496508         17814.7400  104.5900          1
# 2    2.397895  2.302585  1.386294         17867.0350   52.2950          1
# 3    3.091042  2.564949  1.791759         17919.3300   52.2950          1
# 4    3.970292  2.564949  6.725034         17913.0700   -6.2600          0
# ..        ...       ...       ...                ...       ...        ...
# 287  7.098376  6.429719  5.533389         17004.1800 -241.4700          0
# 288  5.402677  5.840642  5.556828         16951.5250  -52.6550          0
# 289  5.648974  5.068904  5.433722         16925.1975  -26.3275          0
# 290  5.730100  6.329721  5.402677         16898.8700  -26.3275          0
# 291  4.595120  5.209486  3.988984                NaN       NaN          0
#
# [292 rows x 12 columns]

# %%
df
# Out:
#            DATE  CLOSING_INDEX   LIKE      HAHA      LOVE   WOW      CARE  \
# 0    2021-07-01     17713.9400   6509  4.948760  4.510860    53  2.484907
# 1    2021-07-02     17710.1500  25305  8.079308  5.220356   386  3.583519
# 2    2021-07-03     17814.7400  11057  4.727388  3.970292    48  2.397895
# 3    2021-07-04     17867.0350  15266  6.091310  3.912023    60  3.091042
# 4    2021-07-05     17919.3300  20674  6.150603  4.836282   992  3.970292
# ..          ...            ...    ...       ...       ...   ...       ...
# 287  2022-04-14     17245.6500  80054  9.173261  6.896694  1610  7.098376
# 288  2022-04-15     17004.1800  60520  9.063463  6.111467  1869  5.402677
# 289  2022-04-16     16951.5250  68885  9.082507  8.037866  2266  5.648974
# 290  2022-04-17     16925.1975  61989  9.128154  7.501634   845  5.730100
# 291  2022-04-18     16898.8700  18213  8.517393  5.056246   269  4.595120
#
#         ANGRY       SAD   L3D_LIKE   L3D_WOW  N1D_CLOSING_INDEX      DIFF  \
# 0    3.713572  2.197225        NaN       NaN         17710.1500   -3.7900
# 1    4.127134  3.496508        NaN       NaN         17814.7400  104.5900
# 2    2.302585  1.386294  10.665951  6.188264         17867.0350   52.2950
# 3    2.564949  1.791759  10.851819  6.202536         17919.3300   52.2950
# 4    2.564949  6.725034  10.757839  7.003065         17913.0700   -6.2600
# ..        ...       ...        ...       ...                ...       ...
# 287  6.429719  5.533389  12.288279  8.320205         17004.1800 -241.4700
# 288  5.840642  5.556828  12.215468  8.518592         16951.5250  -52.6550
# 289  5.068904  5.433722  12.252283  8.656085         16925.1975  -26.3275
# 290  6.329721  5.402677  12.162089  8.513185         16898.8700  -26.3275
# 291  5.209486  3.988984  11.912285  8.125631                NaN       NaN
#
#      DIRECT
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
# ..      ...
# 287       0
# 288       0
# 289       0
# 290       0
# 291       0
#
# [292 rows x 14 columns]

# %%
module1 = ['L3D_LIKE']
module2 = ['L3D_WOW']
module3 = ['L3D_LIKE', 'L3D_WOW']
module4 = ['L3D_LIKE', 'L3D_WOW', 'HAHA', 'LOVE', 'CARE', 'ANGRY', 'SAD']
target = ['DIRECT']

# %%
clf = LogisticRegression()
clf.fit(training[module1], training[target])
print(clf.score(training[module1], training[target]))
print(clf.score(testing[module1], testing[target]))
testing['PRED'] = clf.predict(testing[module1])
testing
# Out:
# 0.6222222222222222
# 0.2916666666666667
# /home/tlyu0419/pyenvs/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_31115/3596474528.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test
# 279  6.257668  4.394449  12.353699  8.137103       17178.630000 -343.870000
# 280  6.721426  5.937536  12.428464  8.435983       17284.540000  105.910000
# 281  5.680173  5.187386  12.272188  8.391403       17166.455000 -118.085000
# 282  4.955827  4.812184  12.148343  8.339740       17107.412500  -59.042500
# 283  4.262680  5.545177  11.946473  7.873978       17048.370000  -59.042500
# 284  5.214936  6.023448  12.260319  7.877018       16990.910000  -57.460000
# 285  5.575949  5.192957  12.350813  8.010360       17301.650000  310.740000
# 286  5.365976  5.908083  12.416419  8.284757       17245.650000  -56.000000
# 287  6.429719  5.533389  12.288279  8.320205       17004.180000 -241.470000
# 288  5.840642  5.556828  12.215468  8.518592       16951.525000  -52.655000
# 289  5.068904  5.433722  12.252283  8.656085       16925.197500  -26.327500
# 290  6.329721  5.402677  12.162089  8.513185       16898.870000  -26.327500
#
#      DIRECT  PRED
# 243       0     1
# 244       1     1
# 245       0     1
# 246       0     1
# 247       0     1
# 248       0     1
# 249       0     1
# 250       1     1
# 251       1     1
# 252       0     1
# 253       0     1
# 254       0     1
# 255       0     1
# 256       0     1
# 257       1     1
# 258       1     1
# 259       1     1
# 260       1     1
# 261       1     1
# 262       1     1
# 263       0     1
# 264       1     1
# 265       0     1
# 266       0     1
# 267       0     1
# 268       0     1
# 269       0     1
# 270       1     1
# 271       1     1
# 272       0     1
# 273       0     1
# 274       0     1
# 275       0     1
# 276       0     1
# 277       0     1
# 278       0     1
# 279       0     1
# 280       1     1
# 281       0     1
# 282       0     1
# 283       0     1
# 284       0     1
# 285       1     1
# 286       0     1
# 287       0     1
# 288       0     1
# 289       0     1
# 290       0     1

# %%
clf = LogisticRegression()
clf.fit(training[module2], training[target])
print(clf.score(training[module2], training[target]))
print(clf.score(testing[module2], testing[target]))
testing['PRED'] = clf.predict(testing[module2])
testing
# Out:
# 0.6222222222222222
# 0.2916666666666667
# /home/tlyu0419/pyenvs/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_31115/1413118797.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing['PRED'] = clf.predict(testing[module2])
#            DATE  CLOSING_INDEX    LIKE       HAHA      LOVE   WOW      CARE  \
# 243  2022-03-01   17898.250000   60371   7.631432  7.153834  1288  6.006353
# 244  2022-03-02   17867.600000   58454   8.336630  5.814131  1626  6.398595
# 245  2022-03-03   17934.400000   56972   9.283219  5.978886  7078  6.200509
# 246  2022-03-04   17736.520000   74795   8.847647  6.639876  1744  7.303843
# 247  2022-03-05   17457.605000   36434   9.231123  5.616771   398  4.691348
# 248  2022-03-06   17318.147500   62376   9.204624  6.942157  1469  5.521461
# 249  2022-03-07   17178.690000   86153   9.125218  7.924796   928  7.367709
# 250  2022-03-08   16825.250000   78121   9.298992  6.883463   828  5.703782
# 251  2022-03-09   17015.360000   42180   8.247220  5.934894   693  6.759255
# 252  2022-03-10   17433.200000   60286   9.208138  6.210600  1199  7.077498
# 253  2022-03-11   17264.740000   93353   9.207236  6.639876  1498  5.416100
# 254  2022-03-12   17263.890000   45429   9.019785  5.796058  1979  5.147494
# 289  5.068904  5.433722  12.252283  8.656085       16925.197500  -26.327500
# 290  6.329721  5.402677  12.162089  8.513185       16898.870000  -26.327500
#
#      DIRECT  PRED
# 243       0     1
# 244       1     1
# 245       0     1
# 246       0     1
# 247       0     1
# 248       0     1
# 249       0     1
# 250       1     1
# 251       1     1
# 252       0     1
# 253       0     1
# 254       0     1
# 255       0     1
# 256       0     1
# 257       1     1
# 258       1     1
# 259       1     1
# 260       1     1
# 261       1     1
# 262       1     1
# 263       0     1
# 264       1     1
# 265       0     1
# 266       0     1
# 267       0     1
# 268       0     1
# 269       0     1
# 270       1     1
# 271       1     1
# 272       0     1
# 273       0     1
# 274       0     1
# 275       0     1
# 276       0     1
# 277       0     1
# 278       0     1
# 279       0     1
# 280       1     1
# 281       0     1
# 282       0     1
# 283       0     1
# 284       0     1
# 285       1     1
# 286       0     1
# 287       0     1
# 288       0     1
# 289       0     1
# 290       0     1

# %%
clf = LogisticRegression()
clf.fit(training[module3], training[target])
print(clf.score(training[module3], training[target]))
print(clf.score(testing[module3], testing[target]))
testing['PRED'] = clf.predict(testing[module3])
testing
# Out:
# 0.6222222222222222
# 0.2916666666666667
# /home/tlyu0419/pyenvs/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_31115/3902095131.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing['PRED'] = clf.predict(testing[module3])
#            DATE  CLOSING_INDEX    LIKE       HAHA      LOVE   WOW      CARE  \
# 243  2022-03-01   17898.250000   60371   7.631432  7.153834  1288  6.006353
# 244  2022-03-02   17867.600000   58454   8.336630  5.814131  1626  6.398595
# 245  2022-03-03   17934.400000   56972   9.283219  5.978886  7078  6.200509
# 246  2022-03-04   17736.520000   74795   8.847647  6.639876  1744  7.303843
# 247  2022-03-05   17457.605000   36434   9.231123  5.616771   398  4.691348
# 248  2022-03-06   17318.147500   62376   9.204624  6.942157  1469  5.521461
# 249  2022-03-07   17178.690000   86153   9.125218  7.924796   928  7.367709
# 250  2022-03-08   16825.250000   78121   9.298992  6.883463   828  5.703782
# 251  2022-03-09   17015.360000   42180   8.247220  5.934894   693  6.759255
# 252  2022-03-10   17433.200000   60286   9.208138  6.210600  1199  7.077498
# 253  2022-03-11   17264.740000   93353   9.207236  6.639876  1498  5.416100
# 254  2022-03-12   17263.890000   45429   9.019785  5.796058  1979  5.147494
# 255  2022-03-13   17263.465000   55579   9.412955  8.132706   685  6.385194
# 256  2022-03-14   17263.040000   47827   9.122165  5.860786  1152  5.105945
# 257  2022-03-15   16926.060000   57565   8.492900  5.720312  1211  4.955827
# 258  2022-03-16   16940.830000   92520  10.058224  8.366138  1107  6.426488
# 259  2022-03-17   17448.220000   91891  10.138757  6.302619  5922  5.602119
# 260  2022-03-18   17456.520000  104564   9.156201  7.550661  5954  6.270988
# 261  2022-03-19   17508.440000   85029   9.784760  8.216628   631  5.955837
# 262  2022-03-20   17534.400000   27492   8.101678  5.402677   335  4.465908
# 263  2022-03-21   17560.360000   74179   9.203819  7.023759  3221  5.926926
# 264  2022-03-22   17559.710000   67407   8.606668  6.467699  1499  5.087596
# 267  4.356709  5.707110  11.742202  7.814400       17598.480000  -78.470000
# 268  5.505332  5.347108  12.203023  7.838343       17559.245000  -39.235000
# 269  3.663562  4.727388  12.338788  8.034307       17520.010000  -39.235000
# 270  4.465908  4.691348  12.360689  8.149891       17548.660000   28.650000
# 271  4.521789  5.283204  12.097986  8.083020       17740.560000  191.900000
# 272  5.587249  6.652863  12.046268  8.105308       17693.470000  -47.090000
# 273  5.602119  5.105945  12.047663  8.030410       17625.590000  -67.880000
# 274  8.703507  5.468060  12.250702  8.547334       17574.045000  -51.545000
# 275  5.283204  7.619724  12.203785  8.435332       17548.272500  -25.772500
# 276  5.726848  8.278428  12.615048  9.004914       17535.386250  -12.886250
# 277  5.375278  5.493061  12.478003  8.730206       17528.943125   -6.443125
# 278  5.231109  5.451038  12.605845  8.838987       17522.500000   -6.443125
# 279  6.257668  4.394449  12.353699  8.137103       17178.630000 -343.870000
# 280  6.721426  5.937536  12.428464  8.435983       17284.540000  105.910000
# 281  5.680173  5.187386  12.272188  8.391403       17166.455000 -118.085000
# 282  4.955827  4.812184  12.148343  8.339740       17107.412500  -59.042500
# 283  4.262680  5.545177  11.946473  7.873978       17048.370000  -59.042500
# 284  5.214936  6.023448  12.260319  7.877018       16990.910000  -57.460000
# 285  5.575949  5.192957  12.350813  8.010360       17301.650000  310.740000
# 286  5.365976  5.908083  12.416419  8.284757       17245.650000  -56.000000
# 287  6.429719  5.533389  12.288279  8.320205       17004.180000 -241.470000
# 288  5.840642  5.556828  12.215468  8.518592       16951.525000  -52.655000
# 289  5.068904  5.433722  12.252283  8.656085       16925.197500  -26.327500
# 290  6.329721  5.402677  12.162089  8.513185       16898.870000  -26.327500
#
#      DIRECT  PRED
# 243       0     1
# 244       1     1
# 245       0     1
# 246       0     1
# 247       0     0
# 248       0     0
# 249       0     1
# 250       1     1
# 251       1     1
# 252       0     1
# 253       0     1
# 254       0     1
# 255       0     0
# 256       0     1
# 257       1     1
# 258       1     1
# 259       1     0
# 260       1     1
# 261       1     0
# 262       1     1
# 263       0     0
# 264       1     1
# 265       0     0
# 266       0     1
# 267       0     1
# 268       0     0
# 269       0     0
# 270       1     1
# 271       1     1
# 272       0     1
# 273       0     1
# 274       0     1
# 275       0     0
# 276       0     1
# 277       0     0
# 278       0     0
# 279       0     1
# 280       1     1
# 281       0     1
# 282       0     0
# 283       0     0
# 284       0     1
# 285       1     1
# 286       0     1
# 287       0     1
# 288       0     1
# 289       0     0
# 290       0     1

# %%
# statmodels
training2 = training[module4]
training2 = sm.add_constant(training2, prepend=False)

# Fit and summarize OLS model
mod = sm.Logit(training[target], training2)
res = mod.fit()

print(res.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.621364
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 DIRECT   No. Observations:                   90
# Model:                          Logit   Df Residuals:                       82
# Method:                           MLE   Df Model:                            7
# Date:                Tue, 19 Apr 2022   Pseudo R-squ.:                 0.06275
# Time:                        23:24:21   Log-Likelihood:                -55.923
# converged:                       True   LL-Null:                       -59.667
# Covariance Type:            nonrobust   LLR p-value:                    0.3799
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# L3D_LIKE      -0.3990      1.037     -0.385      0.701      -2.432       1.634
# L3D_WOW        0.2121      0.658      0.322      0.747      -1.078       1.502
# HAHA          -0.6108      0.376     -1.625      0.104      -1.347       0.126
# LOVE          -0.2094      0.426     -0.492      0.623      -1.044       0.625
# CARE           0.9306      0.495      1.879      0.060      -0.040       1.901
# ANGRY          0.2044      0.358      0.571      0.568      -0.497       0.906
# SAD           -0.3119      0.313     -0.998      0.318      -0.924       0.301
# const          5.6067      7.763      0.722      0.470      -9.608      20.821
# ==============================================================================

# %%
clf = LogisticRegression()
clf.fit(training[module4], training[target])
print(clf.score(training[module4], training[target]))
print(clf.score(testing[module4], testing[target]))
testing['PRED'] = clf.predict(testing[module4])
# testing
# Out:
# 0.6333333333333333
# 0.5208333333333334
# /home/tlyu0419/pyenvs/venv/lib/python3.8/site-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /tmp/ipykernel_31115/435348293.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   testing['PRED'] = clf.predict(testing[module4])

# %%
testing.to_pickle('pred.pkl')

# %% [markdown]
# ## Visualization

# %%
regressor = LinearRegression()
regressor.fit(training[module2], training[target])
print(regressor.score(training[module2], training[target]))
print(regressor.score(testing[module2], testing[target]))

# %%
stock_pred = training[module2]
stock_pred['PRED'] = regressor.predict(training[module2])
stock_pred['N1D_CLOSING_INDEX'] =  training[target]
stock_pred
# Out:
# /tmp/ipykernel_24340/1717904250.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['PRED'] = regressor.predict(training[module2])
# /tmp/ipykernel_24340/1717904250.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['N1D_CLOSING_INDEX'] =  training[target]
#      CLOSING_INDEX  L4D_LIKE      PRED  N1D_CLOSING_INDEX
# 153       0.155651 -0.490039  0.278185           0.439337
# 154       0.439337 -0.574272  0.533599           0.382678
# 155       0.382678 -0.589458  0.483677           0.373558
# 156       0.373558 -0.712353  0.479743           0.368998
# 157       0.368998 -0.721443  0.475994           0.364438
# ..             ...       ...       ...                ...
# 238       0.173135  3.590294  0.154780           0.290846
# 239       0.290846  4.221204  0.238082           0.542148
# 240       0.542148  3.488555  0.486751           0.667799
# 241       0.667799  2.242522  0.641046           0.730624
# 242       0.730624  2.662839  0.682660           0.793450
#
# [90 rows x 4 columns]

# %%
stock_pred = testing[['DATE']+module2]
stock_pred['PRED'] = regressor.predict(testing[module2])
stock_pred['N1D_CLOSING_INDEX'] =  testing[target]
stock_pred
# Out:
# /tmp/ipykernel_24340/3448311257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['PRED'] = regressor.predict(testing[module2])
# /tmp/ipykernel_24340/3448311257.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['N1D_CLOSING_INDEX'] =  testing[target]
#            DATE  CLOSING_INDEX  L4D_LIKE      PRED  N1D_CLOSING_INDEX
# 243  2022-03-01       0.793450  1.936617  0.763323           0.730847
# 244  2022-03-02       0.730847  2.185679  0.699109           0.867287
# 245  2022-03-03       0.867287  1.957675  0.828338           0.463112
# 246  2022-03-04       0.463112  1.329215  0.489935          -0.106579
# 247  2022-03-05      -0.106579  1.073213 -0.008500          -0.391424
# 248  2022-03-06      -0.391424  1.115158 -0.263506          -0.676270
# 249  2022-03-07      -0.676270  1.427244 -0.527712          -1.398180
# 250  2022-03-08      -1.398180  1.462815 -1.171587          -1.009875
# 251  2022-03-09      -1.009875  1.524268 -0.828001          -0.156426
# 252  2022-03-10      -0.156426  1.501915 -0.067477          -0.500510
# 253  2022-03-11      -0.500510  1.578918 -0.376412          -0.502246
# 254  2022-03-12      -0.502246  1.229283 -0.366050          -0.503114
# 255  2022-03-13      -0.503114  1.372583 -0.371703          -0.503983
# 256  2022-03-14      -0.503983  1.239336 -0.367938          -1.192273
# 257  2022-03-15      -1.192273  0.856589 -0.967636          -1.162105
# 258  2022-03-16      -1.162105  1.360220 -0.957933          -0.125748
# 259  2022-03-17      -0.125748  1.748570 -0.048567          -0.108795
# 260  2022-03-18      -0.108795  2.355363 -0.054141          -0.002747
# 261  2022-03-19      -0.002747  2.649085  0.030262           0.050277
# 262  2022-03-20       0.050277  1.953622  0.101151           0.103301
# 263  2022-03-21       0.103301  1.764195  0.154806           0.101973
# 264  2022-03-22       0.101973  1.366808  0.167159           0.452593
# 265  2022-03-23       0.452593  0.912951  0.494748           0.386599
# 266  2022-03-24       0.386599  1.077149  0.430406           0.341439
# 267  2022-03-25       0.341439  0.715161  0.402532           0.181162
# 268  2022-03-26       0.181162  1.237144  0.242071           0.101024
# 269  2022-03-27       0.101024  1.549935  0.160076           0.020885
# 270  2022-03-28       0.020885  1.577143  0.087808           0.079404
# 271  2022-03-29       0.079404  1.811894  0.131908           0.471364
# 272  2022-03-30       0.471364  1.240544  0.500301           0.375182
# 273  2022-03-31       0.375182  0.960212  0.424224           0.236535

# %%
stock_pred['DIFF_PRED'] = stock_pred['PRED'] - stock_pred['CLOSING_INDEX']
stock_pred['DIFF_PRED2'] = stock_pred['DIFF_PRED'].apply(lambda x: int(x>0))
stock_pred['DIFF_ACTU'] = stock_pred['N1D_CLOSING_INDEX'] - stock_pred['CLOSING_INDEX']
stock_pred['DIFF_ACTU2'] = stock_pred['DIFF_ACTU'].apply(lambda x: int(x>0))
stock_pred
# Out:
# /tmp/ipykernel_24340/3883880144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['DIFF_PRED'] = stock_pred['PRED'] - stock_pred['CLOSING_INDEX']
# /tmp/ipykernel_24340/3883880144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['DIFF_PRED2'] = stock_pred['DIFF_PRED'].apply(lambda x: int(x>0))
# /tmp/ipykernel_24340/3883880144.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['DIFF_ACTU'] = stock_pred['N1D_CLOSING_INDEX'] - stock_pred['CLOSING_INDEX']
# /tmp/ipykernel_24340/3883880144.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_pred['DIFF_ACTU2'] = stock_pred['DIFF_ACTU'].apply(lambda x: int(x>0))
#            DATE  CLOSING_INDEX  L4D_LIKE      PRED  N1D_CLOSING_INDEX  \
# 243  2022-03-01       0.793450  1.936617  0.763323           0.730847
# 244  2022-03-02       0.730847  2.185679  0.699109           0.867287
# 245  2022-03-03       0.867287  1.957675  0.828338           0.463112
# 246  2022-03-04       0.463112  1.329215  0.489935          -0.106579
# 247  2022-03-05      -0.106579  1.073213 -0.008500          -0.391424
# 248  2022-03-06      -0.391424  1.115158 -0.263506          -0.676270
# 249  2022-03-07      -0.676270  1.427244 -0.527712          -1.398180
# 250  2022-03-08      -1.398180  1.462815 -1.171587          -1.009875
# 251  2022-03-09      -1.009875  1.524268 -0.828001          -0.156426
# 252  2022-03-10      -0.156426  1.501915 -0.067477          -0.500510
# 253  2022-03-11      -0.500510  1.578918 -0.376412          -0.502246
# 254  2022-03-12      -0.502246  1.229283 -0.366050          -0.503114
# 255  2022-03-13      -0.503114  1.372583 -0.371703          -0.503983
# 256  2022-03-14      -0.503983  1.239336 -0.367938          -1.192273
# 257  2022-03-15      -1.192273  0.856589 -0.967636          -1.162105
# 258  2022-03-16      -1.162105  1.360220 -0.957933          -0.125748
# 259  2022-03-17      -0.125748  1.748570 -0.048567          -0.108795
# 260  2022-03-18      -0.108795  2.355363 -0.054141          -0.002747
# 261  2022-03-19      -0.002747  2.649085  0.030262           0.050277
# 262  2022-03-20       0.050277  1.953622  0.101151           0.103301
# 263  2022-03-21       0.103301  1.764195  0.154806           0.101973
# 264  2022-03-22       0.101973  1.366808  0.167159           0.452593
# 265  2022-03-23       0.452593  0.912951  0.494748           0.386599
# 266  2022-03-24       0.386599  1.077149  0.430406           0.341439
# 267  2022-03-25       0.341439  0.715161  0.402532           0.181162
# 268  2022-03-26       0.181162  1.237144  0.242071           0.101024
# 269  2022-03-27       0.101024  1.549935  0.160076           0.020885
# 270  2022-03-28       0.020885  1.577143  0.087808           0.079404
# 271  2022-03-29       0.079404  1.811894  0.131908           0.471364
# 272  2022-03-30       0.471364  1.240544  0.500301           0.375182
# 273  2022-03-31       0.375182  0.960212  0.424224           0.236535
#
#      DIFF_PRED  DIFF_PRED2  DIFF_ACTU  DIFF_ACTU2
# 243  -0.030127           0  -0.062603           0
# 244  -0.031737           0   0.136441           1
# 245  -0.038950           0  -0.404175           0
# 246   0.026822           1  -0.569691           0
# 247   0.098078           1  -0.284845           0
# 248   0.127918           1  -0.284845           0
# 249   0.148557           1  -0.721910           0
# 250   0.226592           1   0.388304           1
# 251   0.181874           1   0.853449           1
# 252   0.088949           1  -0.344084           0
# 253   0.124098           1  -0.001736           0
# 254   0.136197           1  -0.000868           0
# 255   0.131411           1  -0.000868           0
# 256   0.136045           1  -0.688290           0
# 257   0.224636           1   0.030168           1
# 258   0.204172           1   1.036357           1
# 259   0.077181           1   0.016953           1
# 260   0.054654           1   0.106048           1
# 261   0.033009           1   0.053024           1
# 262   0.050874           1   0.053024           1
# 263   0.051505           1  -0.001328           0
# 264   0.065185           1   0.350620           1
# 265   0.042154           1  -0.065994           0
# 266   0.043806           1  -0.045160           0
# 267   0.061093           1  -0.160277           0
# 268   0.060909           1  -0.080138           0
# 269   0.059053           1  -0.080138           0
# 270   0.066923           1   0.058518           1
# 271   0.052504           1   0.391961           1
# 272   0.028937           1  -0.096183           0
# 273   0.049043           1  -0.138647           0

# %%
stock_pred.groupby(['DIFF_PRED2', 'DIFF_ACTU2']).size().reset_index()
# Out:
#    DIFF_PRED2  DIFF_ACTU2   0
# 0           0           0   2
# 1           0           1   1
# 2           1           0  17
# 3           1           1  11

# %%
stock_pred['']
