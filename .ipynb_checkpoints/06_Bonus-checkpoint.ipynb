# %% [markdown]
# # How to get Comments

# %%
import pandas as pd
import requests
import json
import re

# %% [markdown]
# ## Try1

# %%
url = 'https://www.facebook.com/api/graphql/'
headers = {'accept-language': 'en',
           'content-length': '2254',
           'content-type': 'application/x-www-form-urlencoded',
           'cookie': 'dpr=1.190000057220459; datr=VWxfYmaCRjvG9JnaYZKqA2he',
           'dnt': '1',
           'origin': 'https://www.facebook.com',
           'referer': 'https://www.facebook.com/Gooaye',
           'sec-ch-prefers-color-scheme': 'dark',
           'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Microsoft Edge";v="100"',
           'sec-ch-ua-mobile': '?0',
           'sec-ch-ua-platform': '"Windows"',
           'sec-fetch-dest': 'empty',
           'sec-fetch-mode': 'cors',
           'sec-fetch-site': 'same-origin',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1wq00.0.4896.127 Safari/537.36 Edg/100.0.1185.44',
           'x-fb-friendly-name': 'CometUFICommentsProviderQuery',
           'x-fb-lsd': 'AVpRWquOf90'}
data = {'av': '0',
        '__user': '0',
        '__a': '1',
        '__dyn': '7xeUmwlEnwn8K2WnFw9-2i5U4e0yoW3q322aew9G2S0zU2lwUx609vCwjE1xoswaq0yE5ufz83WwgEcHzo5-0Boy1PwBgao6C0Mo5W3S1lwlE-UqwsUkxe2Gew9O222SUbEaU2eUtw-waCm7-8w4ywJwSyES0QEcU2ZwhF8-4U',
        '__csr': 'gD13Mx5kJax3bQhNcwhGVV4WDjVQrBVJ39bGXFrh4uQh4zeGymFufzppEJ5DyGDjK9AGVEzKGDyrZaEiCCKh1mm8wNAGEaE8C-8h8ORyu5oiAxOiibUryHCx2qm0n616xq0kSewmFEfEcUjw6aw6cw9BpoaUixe0jy0Vo1hE6G2h0jo1m8aE1H8Sdw9J0i8pwQx11K0Vo3pw2y83-wNwo40_E1W-0MU3Nw5Vw6hw2bE1jE0m_wiorgnBg05he02b20k24E6q0y9EDBwdW16yo0MuSq4Z93kVrGcwHw5AK1awGBw52w6ew7rwgo3YwWxu7pFU1IU3RXx4hDgCO0Xxy0B81X82bw4Ig3YyocEf985O1oxe221hwTxi586m8JNg3-xq1ng3Aw4Cw4Aze19wb289G2u3xe1Jwgu0E81glwhojGbgG0B41bw2L83TzU5e3y1Yw5XwLwp8S3OV7okw9ZJ7wfS0lG0a2zUWcU-4A2KCF9E5uVAcxvwaa0j61xK4obU4y5UkCg32w2kE6qE0yG11uUta7ojwefCho1fU66awcJ0KLADjyEyGiiwtUdE2QzQUvK1FAJDxkw2ozo2pwEU2aw6dzE8U0IZ08mBwnE1p8y9wdWcxq4KcUhy8HobU0Aq5By4VbBBw4pyUhwik6E4u9w',
        '__req': 'h',
        '__hs': '19102.HYP:comet_loggedout_pkg.2.0.0.0.',
        'dpr': '1.5',
        '__ccg': 'GOOD',
        '__rev': '1005378023',
        '__s': '2taa32:1i19rl:yvlf4s',
        '__hsi': '7088503855357820612-0',
        '__comet_req': '1',
        'lsd': 'AVpRWquOf90',
        'jazoest': '2948',
        '__spin_r': '1005378023',
        '__spin_b': 'trunk',
        '__spin_t': '1650420915',
        'fb_api_caller_class': 'RelayModern',
        'fb_api_req_friendly_name': 'CometUFICommentsProviderQuery',
        'variables': str({"UFI2CommentsProvider_commentsKey":"ProfileCometTimelineRoute",
                          "__false":'false',
                          "__true":'true',
                          "after":"AQHRjwIsZKt9njkRiF27XWMO2TrChZjjduppzVNXg-NTRwZKPp8hMB21gfuPe12jDRCnH-ghveMzYkr3pZXGQGIp1Q",
                          "before":'null',
                          "displayCommentsContextEnableComment":'null',
                          "displayCommentsContextIsAdPreview":'null',
                          "displayCommentsContextIsAggregatedShare":'null',
                          "displayCommentsContextIsStorySet":'null',
                          "displayCommentsFeedbackContext":'null',
                          "feedLocation":"TIMELINE",
                          "feedbackSource":'0',
                          "first":'50',
                          "focusCommentID":'null',
                          "includeHighlightedComments":'false',
                          "includeNestedComments":'true',
                          "initialViewOption":"RANKED_THREADED",
                          "isInitialFetch":'false',
                          "isPaginating":'true',
                          "last":'null',
                          "scale":'1.5',
                          "topLevelViewOption":'null',
                          "useDefaultActor":'false',
                          "viewOption":'null',
                          "id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0"}),
        'server_timestamps': 'true',
        'doc_id': '5011786355542701'}
resp = requests.post(url, headers=headers, data=data)
resp.text[:3000]
# Out:
# '{"errors":[{"message":"A server error noncoercible_variable_value occured. Check server logs for details.","severity":"CRITICAL","code":1675012,"api_error_code":null,"summary":"Your Request Couldn\'t be Processed","description":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","description_raw":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","is_silent":false,"is_transient":false,"requires_reauth":false,"allow_user_retry":false,"debug_info":null,"query_path":null,"fbtrace_id":"Att6ptLmiU6","www_request_id":"A0Kpc1rPS7Evqd-Jkwp8PqQ"},{"message":"A server error noncoercible_variable_value occured. Check server logs for details.","severity":"CRITICAL","code":1675012,"api_error_code":null,"summary":"Your Request Couldn\'t be Processed","description":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","description_raw":"There was a problem with this reque
# ...

# %% [markdown]
# ## Try2
# - sub 'null' into ''

# %%
url = 'https://www.facebook.com/api/graphql/'
headers = {'accept-language': 'en',
           'content-length': '2254',
           'content-type': 'application/x-www-form-urlencoded',
           'cookie': 'dpr=1.190000057220459; datr=VWxfYmaCRjvG9JnaYZKqA2he',
           'dnt': '1',
           'origin': 'https://www.facebook.com',
           'referer': 'https://www.facebook.com/Gooaye',
           'sec-ch-prefers-color-scheme': 'dark',
           'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Microsoft Edge";v="100"',
           'sec-ch-ua-mobile': '?0',
           'sec-ch-ua-platform': '"Windows"',
           'sec-fetch-dest': 'empty',
           'sec-fetch-mode': 'cors',
           'sec-fetch-site': 'same-origin',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1wq00.0.4896.127 Safari/537.36 Edg/100.0.1185.44',
           'x-fb-friendly-name': 'CometUFICommentsProviderQuery',
           'x-fb-lsd': 'AVpRWquOf90'}
data = {'av': '0',
        '__user': '0',
        '__a': '1',
        '__dyn': '7xeUmwlEnwn8K2WnFw9-2i5U4e0yoW3q322aew9G2S0zU2lwUx609vCwjE1xoswaq0yE5ufz83WwgEcHzo5-0Boy1PwBgao6C0Mo5W3S1lwlE-UqwsUkxe2Gew9O222SUbEaU2eUtw-waCm7-8w4ywJwSyES0QEcU2ZwhF8-4U',
        '__csr': 'gD13Mx5kJax3bQhNcwhGVV4WDjVQrBVJ39bGXFrh4uQh4zeGymFufzppEJ5DyGDjK9AGVEzKGDyrZaEiCCKh1mm8wNAGEaE8C-8h8ORyu5oiAxOiibUryHCx2qm0n616xq0kSewmFEfEcUjw6aw6cw9BpoaUixe0jy0Vo1hE6G2h0jo1m8aE1H8Sdw9J0i8pwQx11K0Vo3pw2y83-wNwo40_E1W-0MU3Nw5Vw6hw2bE1jE0m_wiorgnBg05he02b20k24E6q0y9EDBwdW16yo0MuSq4Z93kVrGcwHw5AK1awGBw52w6ew7rwgo3YwWxu7pFU1IU3RXx4hDgCO0Xxy0B81X82bw4Ig3YyocEf985O1oxe221hwTxi586m8JNg3-xq1ng3Aw4Cw4Aze19wb289G2u3xe1Jwgu0E81glwhojGbgG0B41bw2L83TzU5e3y1Yw5XwLwp8S3OV7okw9ZJ7wfS0lG0a2zUWcU-4A2KCF9E5uVAcxvwaa0j61xK4obU4y5UkCg32w2kE6qE0yG11uUta7ojwefCho1fU66awcJ0KLADjyEyGiiwtUdE2QzQUvK1FAJDxkw2ozo2pwEU2aw6dzE8U0IZ08mBwnE1p8y9wdWcxq4KcUhy8HobU0Aq5By4VbBBw4pyUhwik6E4u9w',
        '__req': 'h',
        '__hs': '19102.HYP:comet_loggedout_pkg.2.0.0.0.',
        'dpr': '1.5',
        '__ccg': 'GOOD',
        '__rev': '1005378023',
        '__s': '2taa32:1i19rl:yvlf4s',
        '__hsi': '7088503855357820612-0',
        '__comet_req': '1',
        'lsd': 'AVpRWquOf90',
        'jazoest': '2948',
        '__spin_r': '1005378023',
        '__spin_b': 'trunk',
        '__spin_t': '1650420915',
        'fb_api_caller_class': 'RelayModern',
        'fb_api_req_friendly_name': 'CometUFICommentsProviderQuery',
        'variables': str({"UFI2CommentsProvider_commentsKey":"ProfileCometTimelineRoute",
                          "__false":'false',
                          "__true":'true',
                          "after":"AQHRjwIsZKt9njkRiF27XWMO2TrChZjjduppzVNXg-NTRwZKPp8hMB21gfuPe12jDRCnH-ghveMzYkr3pZXGQGIp1Q",
                          "before":'',
                          "displayCommentsContextEnableComment":'',
                          "displayCommentsContextIsAdPreview":'',
                          "displayCommentsContextIsAggregatedShare":'',
                          "displayCommentsContextIsStorySet":'',
                          "displayCommentsFeedbackContext":'',
                          "feedLocation":"TIMELINE",
                          "feedbackSource":'0',
                          "first":'50',
                          "focusCommentID":'',
                          "includeHighlightedComments":'false',
                          "includeNestedComments":'true',
                          "initialViewOption":"RANKED_THREADED",
                          "isInitialFetch":'false',
                          "isPaginating":'true',
                          "last":'',
                          "scale":'1.5',
                          "topLevelViewOption":'',
                          "useDefaultActor":'false',
                          "viewOption":'',
                          "id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0"}),
        'server_timestamps': 'true',
        'doc_id': '5011786355542701'}
resp = requests.post(url, headers=headers, data=data)
resp.text[:3000]
# Out:
# '{"errors":[{"message":"A server error noncoercible_variable_value occured. Check server logs for details.","severity":"CRITICAL","code":1675012,"api_error_code":null,"summary":"Your Request Couldn\'t be Processed","description":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","description_raw":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","is_silent":false,"is_transient":false,"requires_reauth":false,"allow_user_retry":false,"debug_info":null,"query_path":null,"fbtrace_id":"Bv4EWWTVaQD","www_request_id":"AmYHWpGQD_N-UTkLOKkYRGh"},{"message":"A server error noncoercible_variable_value occured. Check server logs for details.","severity":"CRITICAL","code":1675012,"api_error_code":null,"summary":"Your Request Couldn\'t be Processed","description":"There was a problem with this request. We\'re working on getting it fixed as soon as we can.","description_raw":"There was a problem with this reque
# ...

# %% [markdown]
# ## Try3

# %%
url = 'https://www.facebook.com/api/graphql/'
headers = {'accept-language': 'en',
           'content-length': '2254',
           'content-type': 'application/x-www-form-urlencoded',
           'cookie': 'dpr=1.190000057220459; datr=VWxfYmaCRjvG9JnaYZKqA2he',
           'dnt': '1',
           'origin': 'https://www.facebook.com',
           'referer': 'https://www.facebook.com/Gooaye',
           'sec-ch-prefers-color-scheme': 'dark',
           'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Microsoft Edge";v="100"',
           'sec-ch-ua-mobile': '?0',
           'sec-ch-ua-platform': '"Windows"',
           'sec-fetch-dest': 'empty',
           'sec-fetch-mode': 'cors',
           'sec-fetch-site': 'same-origin',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1wq00.0.4896.127 Safari/537.36 Edg/100.0.1185.44',
           'x-fb-friendly-name': 'CometUFICommentsProviderQuery',
           'x-fb-lsd': 'AVpRWquOf90'}
data = {'av': '0',
        '__user': '0',
        '__a': '1',
        '__dyn': '7xeUmwlEnwn8K2WnFw9-2i5U4e0yoW3q322aew9G2S0zU2lwUx609vCwjE1xoswaq0yE5ufz83WwgEcHzo5-0Boy1PwBgao6C0Mo5W3S1lwlE-UqwsUkxe2Gew9O222SUbEaU2eUtw-waCm7-8w4ywJwSyES0QEcU2ZwhF8-4U',
        '__csr': 'gD13Mx5kJax3bQhNcwhGVV4WDjVQrBVJ39bGXFrh4uQh4zeGymFufzppEJ5DyGDjK9AGVEzKGDyrZaEiCCKh1mm8wNAGEaE8C-8h8ORyu5oiAxOiibUryHCx2qm0n616xq0kSewmFEfEcUjw6aw6cw9BpoaUixe0jy0Vo1hE6G2h0jo1m8aE1H8Sdw9J0i8pwQx11K0Vo3pw2y83-wNwo40_E1W-0MU3Nw5Vw6hw2bE1jE0m_wiorgnBg05he02b20k24E6q0y9EDBwdW16yo0MuSq4Z93kVrGcwHw5AK1awGBw52w6ew7rwgo3YwWxu7pFU1IU3RXx4hDgCO0Xxy0B81X82bw4Ig3YyocEf985O1oxe221hwTxi586m8JNg3-xq1ng3Aw4Cw4Aze19wb289G2u3xe1Jwgu0E81glwhojGbgG0B41bw2L83TzU5e3y1Yw5XwLwp8S3OV7okw9ZJ7wfS0lG0a2zUWcU-4A2KCF9E5uVAcxvwaa0j61xK4obU4y5UkCg32w2kE6qE0yG11uUta7ojwefCho1fU66awcJ0KLADjyEyGiiwtUdE2QzQUvK1FAJDxkw2ozo2pwEU2aw6dzE8U0IZ08mBwnE1p8y9wdWcxq4KcUhy8HobU0Aq5By4VbBBw4pyUhwik6E4u9w',
        '__req': 'h',
        '__hs': '19102.HYP:comet_loggedout_pkg.2.0.0.0.',
        'dpr': '1.5',
        '__ccg': 'GOOD',
        '__rev': '1005378023',
        '__s': '2taa32:1i19rl:yvlf4s',
        '__hsi': '7088503855357820612-0',
        '__comet_req': '1',
        'lsd': 'AVpRWquOf90',
        'jazoest': '2948',
        '__spin_r': '1005378023',
        '__spin_b': 'trunk',
        '__spin_t': '1650420915',
        'fb_api_caller_class': 'RelayModern',
        'fb_api_req_friendly_name': 'CometUFICommentsProviderQuery',
        'variables': str({"UFI2CommentsProvider_commentsKey":"ProfileCometTimelineRoute",
                          "__false":'false',
                          "__true":'true',
                          "after":"AQHRjwIsZKt9njkRiF27XWMO2TrChZjjduppzVNXg-NTRwZKPp8hMB21gfuPe12jDRCnH-ghveMzYkr3pZXGQGIp1Q",
                          # "before":'',
                          # "displayCommentsContextEnableComment":'',
                          # "displayCommentsContextIsAdPreview":'',
                          # "displayCommentsContextIsAggregatedShare":'',
                          # "displayCommentsContextIsStorySet":'',
                          # "displayCommentsFeedbackContext":'',
                          "feedLocation":"TIMELINE",
                          "feedbackSource":'0',
                          "first":'50',
                          # "focusCommentID":'',
                          "includeHighlightedComments":'false',
                          "includeNestedComments":'true',
                          "initialViewOption":"RANKED_THREADED",
                          "isInitialFetch":'false',
                          "isPaginating":'true',
                          # "last":'',
                          "scale":'1.5',
                          # "topLevelViewOption":'',
                          "useDefaultActor":'false',
                          # "viewOption":'',
                          "id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0"}),
        'server_timestamps': 'true',
        'doc_id': '5011786355542701'}
resp = requests.post(url, headers=headers, data=data)
resp.text[:3000]
# Out:
# '{"data":{"node":{"__typename":"Feedback","id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0","subscription_target_id":"518456913062174","display_comments":{"after_count":51,"before_count":51,"count":796,"edges":[{"node":{"id":"Y29tbWVudDo1MTg0NTY5MTMwNjIxNzRfNTE4NDc0OTE2MzkzNzA3","legacy_fbid":"518474916393707","author":{"__typename":"User","id":"100000092911115","name":"\\u5f35\\u7b71\\u4e8e","__isActor":"User","profile_picture_depth_0":{"uri":"https:\\/\\/scontent.ftpe2-2.fna.fbcdn.net\\/v\\/t1.6435-1\\/140077322_4031364770209914_546037399336918747_n.jpg?stp=cp0_dst-jpg_p48x48&_nc_cat=108&ccb=1-5&_nc_sid=7206a8&_nc_ohc=jNOo8NGWWwgAX8Ci-YF&_nc_ht=scontent.ftpe2-2.fna&oh=00_AT_bJ0dcny2fiRreHKmuxQCMTZ7B14A5XZqDAwWLMSE73g&oe=628698CB"},"profile_picture_depth_1":{"uri":"https:\\/\\/scontent.ftpe2-2.fna.fbcdn.net\\/v\\/t1.6435-1\\/140077322_4031364770209914_546037399336918747_n.jpg?stp=cp0_dst-jpg_p40x40&_nc_cat=108&ccb=1-5&_nc_sid=7206a8&_nc_ohc=jNOo8NGWWwgAX8Ci-YF&_nc_ht=scontent.ftpe2-2.fna&oh=0
# ...

# %% [markdown]
# ## 簡化參數1

# %%
url = 'https://www.facebook.com/api/graphql/'
headers = {'accept-language': 'en',
           # 'content-length': '2254',
           'content-type': 'application/x-www-form-urlencoded',
           'cookie': 'dpr=1.190000057220459; datr=VWxfYmaCRjvG9JnaYZKqA2he',
           'dnt': '1',
           'origin': 'https://www.facebook.com',
           'referer': 'https://www.facebook.com/Gooaye',
           # 'sec-ch-prefers-color-scheme': 'dark',
           # 'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="100", "Microsoft Edge";v="100"',
           # 'sec-ch-ua-mobile': '?0',
           # 'sec-ch-ua-platform': '"Windows"',
           'sec-fetch-dest': 'empty',
           'sec-fetch-mode': 'cors',
           'sec-fetch-site': 'same-origin',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1wq00.0.4896.127 Safari/537.36 Edg/100.0.1185.44',
           'x-fb-friendly-name': 'CometUFICommentsProviderQuery',
           # 'x-fb-lsd': 'AVpRWquOf90'
          }
data = {#'av': '0',
        # '__user': '0',
        # '__a': '1',
        # '__dyn': '7xeUmwlEnwn8K2WnFw9-2i5U4e0yoW3q322aew9G2S0zU2lwUx609vCwjE1xoswaq0yE5ufz83WwgEcHzo5-0Boy1PwBgao6C0Mo5W3S1lwlE-UqwsUkxe2Gew9O222SUbEaU2eUtw-waCm7-8w4ywJwSyES0QEcU2ZwhF8-4U',
        '__csr': 'gD13Mx5kJax3bQhNcwhGVV4WDjVQrBVJ39bGXFrh4uQh4zeGymFufzppEJ5DyGDjK9AGVEzKGDyrZaEiCCKh1mm8wNAGEaE8C-8h8ORyu5oiAxOiibUryHCx2qm0n616xq0kSewmFEfEcUjw6aw6cw9BpoaUixe0jy0Vo1hE6G2h0jo1m8aE1H8Sdw9J0i8pwQx11K0Vo3pw2y83-wNwo40_E1W-0MU3Nw5Vw6hw2bE1jE0m_wiorgnBg05he02b20k24E6q0y9EDBwdW16yo0MuSq4Z93kVrGcwHw5AK1awGBw52w6ew7rwgo3YwWxu7pFU1IU3RXx4hDgCO0Xxy0B81X82bw4Ig3YyocEf985O1oxe221hwTxi586m8JNg3-xq1ng3Aw4Cw4Aze19wb289G2u3xe1Jwgu0E81glwhojGbgG0B41bw2L83TzU5e3y1Yw5XwLwp8S3OV7okw9ZJ7wfS0lG0a2zUWcU-4A2KCF9E5uVAcxvwaa0j61xK4obU4y5UkCg32w2kE6qE0yG11uUta7ojwefCho1fU66awcJ0KLADjyEyGiiwtUdE2QzQUvK1FAJDxkw2ozo2pwEU2aw6dzE8U0IZ08mBwnE1p8y9wdWcxq4KcUhy8HobU0Aq5By4VbBBw4pyUhwik6E4u9w',
        # '__req': 'h',
        # '__hs': '19102.HYP:comet_loggedout_pkg.2.0.0.0.',
        # 'dpr': '1.5',
        # '__ccg': 'GOOD',
        # '__rev': '1005378023',
        # '__s': '2taa32:1i19rl:yvlf4s',
        # '__hsi': '7088503855357820612-0',
        # '__comet_req': '1',
        # 'lsd': 'AVpRWquOf90',
        # 'jazoest': '2948',
        # '__spin_r': '1005378023',
        # '__spin_b': 'trunk',
        # '__spin_t': '1650420915',
        'fb_api_caller_class': 'RelayModern',
        'fb_api_req_friendly_name': 'CometUFICommentsProviderQuery',
        'variables': str({"UFI2CommentsProvider_commentsKey":"ProfileCometTimelineRoute",
                          # "__false":'false',
                          # "__true":'true',
                          "after":"AQHRjwIsZKt9njkRiF27XWMO2TrChZjjduppzVNXg-NTRwZKPp8hMB21gfuPe12jDRCnH-ghveMzYkr3pZXGQGIp1Q",
                          # "before":'',
                          # "displayCommentsContextEnableComment":'',
                          # "displayCommentsContextIsAdPreview":'',
                          # "displayCommentsContextIsAggregatedShare":'',
                          # "displayCommentsContextIsStorySet":'',
                          # "displayCommentsFeedbackContext":'',
                          # "feedLocation":"TIMELINE",
                          # "feedbackSource":'0',
                          "first":'50',
                          # "focusCommentID":'',
                          # "includeHighlightedComments":'false',
                          # "includeNestedComments":'true',
                          # "initialViewOption":"RANKED_THREADED",
                          # "isInitialFetch":'false',
                          # "isPaginating":'true',
                          # "last":'',
                          # "scale":'1.5',
                          # "topLevelViewOption":'',
                          # "useDefaultActor":'false',
                          # "viewOption":'',
                          "id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0"}),
        # 'server_timestamps': 'true',
        'doc_id': '5011786355542701'}
resp = requests.post(url, headers=headers, data=data)
resp.text[:3000]
# Out:
# '{"data":{"node":{"__typename":"Feedback","id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0","subscription_target_id":"518456913062174","display_comments":{"highlighted_comments":[],"comment_order":"RANKED_THREADED","expanded_sub_reply_parents":[],"is_initially_expanded":true,"page_size":10,"reply_comment_order":"RANKED_REPLIES","should_render_composer_preemptively":true,"after_count":11,"before_count":11,"count":796,"edges":[{"node":{"id":"Y29tbWVudDo1MTg0NTY5MTMwNjIxNzRfNTE4NDc0OTE2MzkzNzA3","legacy_fbid":"518474916393707","author":{"__typename":"User","id":"100000092911115","name":"\\u5f35\\u7b71\\u4e8e","__isActor":"User","profile_picture_depth_0":{"uri":"https:\\/\\/scontent.ftpe2-2.fna.fbcdn.net\\/v\\/t1.6435-1\\/140077322_4031364770209914_546037399336918747_n.jpg?stp=cp0_dst-jpg_p48x48&_nc_cat=108&ccb=1-5&_nc_sid=7206a8&_nc_ohc=jNOo8NGWWwgAX8Ci-YF&_nc_ht=scontent.ftpe2-2.fna&oh=00_AT_bJ0dcny2fiRreHKmuxQCMTZ7B14A5XZqDAwWLMSE73g&oe=628698CB"},"profile_picture_depth_1":{"uri":"https:\\/\\/s
# ...

# %% [markdown]
# ## 簡化參數2

# %%
url = 'https://www.facebook.com/api/graphql/'
headers = {'accept-language': 'en',
           'content-type': 'application/x-www-form-urlencoded',
           'cookie': 'dpr=1.190000057220459; datr=VWxfYmaCRjvG9JnaYZKqA2he',
           'origin': 'https://www.facebook.com',
           'referer': 'https://www.facebook.com/Gooaye',
           'sec-fetch-dest': 'empty',
           'sec-fetch-mode': 'cors',
           'sec-fetch-site': 'same-origin',
           'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/1wq00.0.4896.127 Safari/537.36 Edg/100.0.1185.44',
           'x-fb-friendly-name': 'CometUFICommentsProviderQuery'
          }
data = {'fb_api_caller_class': 'RelayModern',
        'fb_api_req_friendly_name': 'CometUFICommentsProviderQuery',
        'variables': str({"UFI2CommentsProvider_commentsKey":"ProfileCometTimelineRoute",
                          "after":"AQHRjwIsZKt9njkRiF27XWMO2TrChZjjduppzVNXg-NTRwZKPp8hMB21gfuPe12jDRCnH-ghveMzYkr3pZXGQGIp1Q",
                          "first":'50',
                          "id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0"}),
        'doc_id': '5011786355542701'}
resp = requests.post(url, headers=headers, data=data)
resp.text[:3000]
# Out:
# '{"data":{"node":{"__typename":"Feedback","id":"ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0","subscription_target_id":"518456913062174","display_comments":{"highlighted_comments":[],"comment_order":"RANKED_THREADED","expanded_sub_reply_parents":[],"is_initially_expanded":true,"page_size":10,"reply_comment_order":"RANKED_REPLIES","should_render_composer_preemptively":true,"after_count":11,"before_count":11,"count":796,"edges":[{"node":{"id":"Y29tbWVudDo1MTg0NTY5MTMwNjIxNzRfNTE4NDc0OTE2MzkzNzA3","legacy_fbid":"518474916393707","author":{"__typename":"User","id":"100000092911115","name":"\\u5f35\\u7b71\\u4e8e","__isActor":"User","profile_picture_depth_0":{"uri":"https:\\/\\/scontent.ftpe2-2.fna.fbcdn.net\\/v\\/t1.6435-1\\/140077322_4031364770209914_546037399336918747_n.jpg?stp=cp0_dst-jpg_p48x48&_nc_cat=108&ccb=1-5&_nc_sid=7206a8&_nc_ohc=jNOo8NGWWwgAX8Ci-YF&_nc_ht=scontent.ftpe2-2.fna&oh=00_AT_bJ0dcny2fiRreHKmuxQCMTZ7B14A5XZqDAwWLMSE73g&oe=628698CB"},"profile_picture_depth_1":{"uri":"https:\\/\\/s
# ...

# %% [markdown]
# ## parsing

# %%
len(resp.text.split('\r\n', -1))
# Out:
# 2

# %%
resp1 = resp.text.split('\r\n', -1)[0]
resp2 = resp.text.split('\r\n', -1)[1]

# %%
json.loads(resp1).keys()
# Out:
# dict_keys(['data', 'errors', 'extensions'])

# %%
json.loads(resp1)['data']['node'].keys()
# Out:
# dict_keys(['__typename', 'id', 'subscription_target_id', 'display_comments'])

# %%
json.loads(resp1)['data']['node']['__typename']
# Out:
# 'Feedback'

# %%
json.loads(resp1)['data']['node']['id']
# Out:
# 'ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0'

# %%
json.loads(resp1)['data']['node']['subscription_target_id']
# Out:
# '518456913062174'

# %%
json.loads(resp1)['data']['node']['display_comments'].keys()
# Out:
# dict_keys(['highlighted_comments', 'comment_order', 'expanded_sub_reply_parents', 'is_initially_expanded', 'page_size', 'reply_comment_order', 'should_render_composer_preemptively', 'after_count', 'before_count', 'count', 'edges', 'page_info'])

# %%
json.loads(resp1)['data']['node']['display_comments']['after_count']
# Out:
# 11

# %%
json.loads(resp1)['data']['node']['display_comments']['before_count']
# Out:
# 11

# %%
# 總留言數
json.loads(resp1)['data']['node']['display_comments']['count']
# Out:
# 796

# %%
json.loads(resp1)['data']['node']['display_comments']['page_info']
# Out:
# {'end_cursor': 'AQHRuMcs-5mJ44hf6yl6Sgs3y3Lcfk2UC9VT-vJNi-WQmUTVPKZ2gfQ1H82-soWOJlxxQWIUa1Zvd85jIWRA5etrmw',
#  'has_next_page': True,
#  'has_previous_page': True,
#  'start_cursor': 'AQHReiT5qlR-S-wonA62onC4eovzFfvJITk3wLjLYkT9VjlQq0JxlL2Kib4RDHfb51ardbdODKMgT_RGyJEYQbms3Q'}

# %%
# 留言內容
len(json.loads(resp1)['data']['node']['display_comments']['edges'])
# Out:
# 50

# %%
for edge in json.loads(resp1)['data']['node']['display_comments']['edges']:
    print('cursor: ', edge['cursor'])
    print('id: ', edge['node']['id'])
    print('legacy_fbid: ', edge['node']['legacy_fbid'])
    print('author__typename: ', edge['node']['author']['__typename'])
    print('author_id: ', edge['node']['author']['id'])
    print('author_name: ', edge['node']['author']['name'])
    print('author_url: ', edge['node']['author']['url'])
    print('created_time: ', edge['node']['created_time'])
    print('feedback_id: ', edge['node']['feedback']['id'])
    print('feedback_reactors: ', edge['node']['feedback']['reactors']['count'])
    print('feedback_comment_count: ', edge['node']['feedback']['comment_count']['total_count'])
    print('feedback_toplevel_comment_count: ', edge['node']['feedback']['toplevel_comment_count']['count'])
    print('subscription_target_id: ', edge['node']['feedback']['subscription_target_id'])
    print('parent_feedback_id: ', edge['node']['parent_feedback']['id'])
    print('parent_feedback_share_fbid: ', edge['node']['parent_feedback']['share_fbid'])
    print('parent_feedback_owning_profile_name: ', edge['node']['parent_feedback']['owning_profile']['name'])
    print('parent_feedback_owning_profile_id: ', edge['node']['parent_feedback']['owning_profile']['id'])
    print('comment_url: ', edge['node']['url'])
    print('legacy_token: ', edge['node']['legacy_token'])
    print('text: ', edge['node']['body']['text'])
    print('__typename: ', edge['node']['__typename'])
    print('========================================================================================================')
    print('========================================================================================================')
# Out:
# cursor:  AQHRupxcky8MNzXfM1hR3BQEHmCqWdDwidcisx8DGvu8lCDrVMwxbkPHOkoRRtOgYrhjga9lBAV5u08wGfgEC6GlPg
# id:  Y29tbWVudDo1MTg0NTY5MTMwNjIxNzRfNTE4NDc0OTE2MzkzNzA3
# legacy_fbid:  518474916393707
# author__typename:  User
# author_id:  100000092911115
# author_name:  張筱于
# author_url:  None
# created_time:  1650279910
# feedback_id:  ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0XzUxODQ3NDkxNjM5MzcwNw==
# feedback_reactors:  9
# feedback_comment_count:  10
# feedback_toplevel_comment_count:  10
# subscription_target_id:  518474916393707
# parent_feedback_id:  ZmVlZGJhY2s6NTE4NDU2OTEzMDYyMTc0
# parent_feedback_share_fbid:  518456913062174
# parent_feedback_owning_profile_name:  股癌 Gooaye
# parent_feedback_owning_profile_id:  100046936094218
# comment_url:  https://www.facebook.com/Gooaye/posts/pfbid0SPCAew7R9aYtkLtkunzmVAdWDEi7gq5v59UFAereEvbieDFNutPMFGYv2g2TLzBCl?comment_id=518474916393707
# legacy_token:  518456913062174_518474916393707
# text:  旺旺
# __typename:  Comment
# ...

# %% [markdown]
# ## How to get more comment
# - keep the cursor information into grapfql

# %% [markdown]
# ## how to get the replies of comments
# - Put the comment id in to graphql
